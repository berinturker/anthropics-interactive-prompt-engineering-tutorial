# %% [markdown]
# # Chapter 2: Being Clear and Direct
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
API_KEY = ""
MODEL_NAME = "claude-haiku-4-5-20251001"

# Stores the API_KEY & MODEL_NAME variables for use across notebooks within the IPython store
# %store API_KEY
# %store MODEL_NAME
# Out:
# Stored 'API_KEY' (str)
# Stored 'MODEL_NAME' (str)

# %%
# !pip install anthropic

# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

# Note that we changed max_tokens to 4K just for this lesson to allow for longer completions in the exercises
def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=4000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /usr/local/lib/python3.12/dist-packages (0.116.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)

# %% [markdown]
# ---
#
# ## Lesson
#
# **Claude responds best to clear and direct instructions.**
#
# Think of Claude like any other human that is new to the job. **Claude has no context** on what to do aside from what you literally tell it. Just as when you instruct a human for the first time on a task, the more you explain exactly what you want in a straightforward manner to Claude, the better and more accurate Claude's response will be."
#
# When in doubt, follow the **Golden Rule of Clear Prompting**:
# - Show your prompt to a colleague or friend and have them follow the instructions themselves to see if they can produce the result you want. If they're confused, Claude's confused.

# %% [markdown]
# ### Examples
#
# Let's take a task like writing poetry. (Ignore any syllable mismatch - LLMs aren't great at counting syllables yet.)

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# This haiku is nice enough, but users may want Claude to go directly into the poem without the "Here is a haiku" preamble.
#
# How do we achieve that? We **ask for it**!

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Here's another example. Let's ask Claude who's the best basketball player of all time. You can see below that while Claude lists a few names, **it doesn't respond with a definitive "best"**.

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Can we get Claude to make up its mind and decide on a best player? Yes! Just ask!

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 2.1 - Spanish](#exercise-21---spanish)
# - [Exercise 2.2 - One Player Only](#exercise-22---one-player-only)
# - [Exercise 2.3 - Write a Story](#exercise-23---write-a-story)

# %% [markdown]
# ### Exercise 2.1 - Spanish
# Modify the `SYSTEM_PROMPT` to make Claude output its answer in Spanish.

# %%
# System prompt - this is the only field you should chnage
SYSTEM_PROMPT = "answer in spanish"

# Prompt
PROMPT = "Hello Claude, how are you?"

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return "hola" in text.lower()

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# ¡Hola! Estoy bien, gracias por preguntar. Me alegra saludarte. ¿Cómo estás tú? ¿En qué puedo ayudarte hoy?
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_1_hint; print(exercise_2_1_hint)

# %% [markdown]
# ### Exercise 2.2 - One Player Only
#
# Modify the `PROMPT` so that Claude doesn't equivocate at all and responds with **ONLY** the name of one specific player, with **no other words or punctuation**.

# %%
# Prompt - this is the only field you should change
PROMPT = "Who is the best basketball player of all time? respond only the name and surname"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    return text == "Michael Jordan"

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# Michael Jordan
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_2_hint; print(exercise_2_2_hint)

# %% [markdown]
# ### Exercise 2.3 - Write a Story
#
# Modify the `PROMPT` so that Claude responds with as long a response as you can muster. If your answer is **over 800 words**, Claude's response will be graded as correct.

# %%
# Prompt - this is the only field you should change
PROMPT = "write me a story that is at least 800 words"

# Get Claude's response
response = get_completion(PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    trimmed = text.strip()
    words = len(trimmed.split())
    return words >= 800

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))
# Out:
# # The Lighthouse Keeper's Secret
#
# The storm had been building for three days when old Thomas finally decided to tell someone the truth. He stood at the top of the lighthouse, watching the dark clouds roll across the Atlantic like an invading army, and knew that time was running out.
#
# Thomas had kept the Beacon Point Lighthouse for forty-two years. He'd arrived as a young man of twenty-three, fresh from the merchant marines, eager for a quiet life away from the chaos of the world. The lighthouse had been his sanctuary, his home, his entire universe. He'd never married, never left the island for more than a day, never questioned his purpose. The light had to shine every night, and he was the one to make sure it did.
#
# But there was something else. Something he'd never told anyone.
#
# It started in his third year at the lighthouse. Thomas had been climbing the spiral stairs one evening when he heard it—a sound like singing, but not quite. It was beautiful and haunting, coming from somewhere above him. He'd rushed to the lamp room, expecting to find an intruder, but there was nothing. Only the great Fresnel lens rotating steadily, casting its beam across the dark water.
#
# The next night, he heard it again.
#
# Over the following weeks, Thomas became obsessed with discovering the source of the mysterious sound. He searched every corner of the lighthouse, questioned the supply boat captain, even contacted the mainland authorities. No one could explain it. But Thomas knew he wasn't imagining it. The sound was real, and it only came on certain nights—always when the weather was turning, always when storms approached.
#
# Years passed. Thomas stopped trying to explain the phenomenon and simply accepted it as part of his life. He began to anticipate the sound, to listen for it with a mixture of fear and longing. He started keeping detailed records of when it occurred, what the weather was like, what phase the moon was in. Patterns emerged. The sound came exactly three days before major storms. It was a warning.
#
# Using this knowledge, Thomas had saved countless lives. He'd alert the coast guard about approaching vessels, recommend that fishing boats return to harbor, warn the few residents of the island to prepare for severe weather. His predictions were uncannily accurate. People called him a weather wizard, a man with an instinct for the sea. They had no idea about the voice.
#
# Thomas never told anyone because he knew how it would sound. A man hearing mysterious voices in a lighthouse? They'd remove him, replace him, lock him away in some institution. And the light would go on, but the warning would be lost. The voice had become his responsibility, his sacred trust.
#
# As the years accumulated, Thomas grew older. His hair turned white, his hands became gnarled, his knees ached with every climb up the spiral stairs. He began to worry about what would happen when he could no longer tend the light. The Coast Guard had been talking about automating the lighthouse for years. Soon, they said, they wouldn't need a keeper anymore. The light would shine automatically, controlled by computers and sensors from the mainland.
#
# When that happened, no one would hear the voice. No one would know about the warnings.
#
# Three days ago, Thomas had heard it again—louder and more insistent than ever before. The sound had filled the lamp room, almost like words, almost like a plea. And Thomas had finally understood. The voice wasn't warning him about the storms. It was warning him that time was running out. It was telling him to pass on the knowledge before it was too late.
#
# So on this gray afternoon, with the storm building and the wind howling around the lighthouse, Thomas made a phone call. He asked for Sarah Chen, the young journalist who'd written an article about him last year. When she answered, he took a deep breath and began to speak.
#
# "I have a story to tell you," he said. "A true story. And I need you to believe me, because lives depend on it."
#
# Sarah arrived on the supply boat the next morning, skeptical but curious. Thomas spent the entire day showing her his records—forty years of meticulous documentation. He played her recordings he'd made on old cassette tapes, capturing the mysterious sound. He explained the patterns, the accuracy of his predictions, the impossible knowledge he'd somehow possessed.
#
# That night, as the storm raged outside, they waited together in the lamp room. And at exactly 11:47 PM, it came—the sound. Sarah heard it too. Her face went pale, her eyes wide with wonder and fear.
#
# "What is it?" she whispered.
#
# Thomas smiled, feeling a weight lift from his shoulders. "I don't know," he said honestly. "But it's real. And now you know it too."
#
# The next morning, Sarah's article went viral. Scientists came to investigate. Theories emerged—unusual acoustic phenomena, electromagnetic anomalies, something about the unique geology of the island. No one could explain it definitively, but no one could deny it either.
#
# Thomas retired six months later, but not before training Sarah to listen for the voice. The lighthouse was automated, but Sarah visited every week, keeping the old tradition alive, maintaining the connection between the human world and whatever mystery dwelt in that tower by the sea.
#
# And the light continued to shine, warning ships of danger, just as it always had.
#
# --------------------------- GRADING ---------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_2_3_hint; print(exercise_2_3_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "Write a haiku about robots."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Write a haiku about robots. Skip the preamble; go straight into the poem."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Who is the best basketball player of all time? Yes, there are differing opinions, but if you absolutely had to pick one player, who would it be?"

# Print Claude's response
print(get_completion(PROMPT))
